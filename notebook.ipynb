# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** Muhammad Hanif Adiprana
# - **Email:** hanifadiprana123@gmail.com
# - **ID Dicoding:** MUHAMMAD HANIF ADIPRANA

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana tren temperatur pada tahun 2016 di China
# - Berapa nilai maksimum dan minimum dari temperatur tersebut

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install plotly
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 73.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
Aotizhongxin= pd.read_csv('PRSA_Data_Aotizhongxin_20130301-20170228.csv')
Changping= pd.read_csv('PRSA_Data_Changping_20130301-20170228.csv')
Dingling= pd.read_csv('PRSA_Data_Dingling_20130301-20170228.csv')
Dongsi= pd.read_csv('PRSA_Data_Dongsi_20130301-20170228.csv')
Guanyuan= pd.read_csv('PRSA_Data_Guanyuan_20130301-20170228.csv')
Gucheng= pd.read_csv('PRSA_Data_Gucheng_20130301-20170228.csv')
Huairou= pd.read_csv('PRSA_Data_Huairou_20130301-20170228.csv')
Nongzhanguan= pd.read_csv('PRSA_Data_Nongzhanguan_20130301-20170228.csv')
Shunyi= pd.read_csv('PRSA_Data_Shunyi_20130301-20170228.csv')
Tiantan= pd.read_csv('PRSA_Data_Tiantan_20130301-20170228.csv')
Wanliu= pd.read_csv('PRSA_Data_Wanliu_20130301-20170228.csv')
Wanshouxigong= pd.read_csv('PRSA_Data_Wanshouxigong_20130301-20170228.csv')

df = pd.concat([Aotizhongxin, Changping, Dingling, Dongsi, Guanyuan, Gucheng, Huairou, Nongzhanguan, Shunyi, Tiantan, Wanliu, Wanshouxigong])

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %%
print(df)
df.to_csv('COMPILED.csv', index=False)
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   11.0  32.0   3.0  24.0  400.0  72.0
# 35060  35061  2017      2   28    20   13.0  32.0   3.0  41.0  500.0  50.0
# 35061  35062  2017      2   28    21   14.0  28.0   4.0  38.0  500.0  54.0
# 35062  35063  2017      2   28    22   12.0  23.0   4.0  30.0  400.0  59.0
# 35063  35064  2017      2   28    23   13.0  19.0   4.0  38.0  600.0  49.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM        station
# ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %%
df_2016= df[df['year'] == 2016]

# %%
print(df_2016)
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  \
# 24864  24865  2016      1    1     0  209.0  268.0  47.0  123.0  5300.0  13.0
# 24865  24866  2016      1    1     1  211.0  248.0  66.0  119.0  5400.0  16.0
# 24866  24867  2016      1    1     2  167.0  192.0  64.0  115.0  4300.0  12.0
# 24867  24868  2016      1    1     3  136.0  159.0  56.0  111.0  4100.0   9.0
# 24868  24869  2016      1    1     4  108.0  121.0  46.0  107.0  3600.0   7.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...   ...
# 33643  33644  2016     12   31    19  449.0  487.0  10.0  153.0  4500.0   4.0
# 33644  33645  2016     12   31    20  460.0  492.0  12.0  146.0  4100.0   4.0
# 33645  33646  2016     12   31    21  463.0  498.0  12.0  141.0  4400.0   5.0
# 33646  33647  2016     12   31    22  493.0  537.0  12.0  124.0  5000.0   8.0
# 33647  33648  2016     12   31    23  464.0  490.0   8.0  111.0  5400.0   7.0
#
# ...

# %% [markdown]
# **Insight:**
# - Data terpotong pada tahun 2013 dan 2017. Maka dipilih tahun terbaru dengan data yang komplit.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
print(df_2016)
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  \
# 24864  24865  2016      1    1     0  209.0  268.0  47.0  123.0  5300.0  13.0
# 24865  24866  2016      1    1     1  211.0  248.0  66.0  119.0  5400.0  16.0
# 24866  24867  2016      1    1     2  167.0  192.0  64.0  115.0  4300.0  12.0
# 24867  24868  2016      1    1     3  136.0  159.0  56.0  111.0  4100.0   9.0
# 24868  24869  2016      1    1     4  108.0  121.0  46.0  107.0  3600.0   7.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...   ...
# 33643  33644  2016     12   31    19  449.0  487.0  10.0  153.0  4500.0   4.0
# 33644  33645  2016     12   31    20  460.0  492.0  12.0  146.0  4100.0   4.0
# 33645  33646  2016     12   31    21  463.0  498.0  12.0  141.0  4400.0   5.0
# 33646  33647  2016     12   31    22  493.0  537.0  12.0  124.0  5000.0   8.0
# 33647  33648  2016     12   31    23  464.0  490.0   8.0  111.0  5400.0   7.0
#
# ...

# %%
rain_data = df_2016.groupby(['station','month'])['RAIN'].sum().reset_index()
print(rain_data)
rain_data.to_csv('rain_data.csv', index=False)
# Out:
#            station  month   RAIN
# 0     Aotizhongxin      1    0.5
# 1     Aotizhongxin      2   12.6
# 2     Aotizhongxin      3    0.0
# 3     Aotizhongxin      4    4.8
# 4     Aotizhongxin      5   34.1
# ..             ...    ...    ...
# 139  Wanshouxigong      8   53.9
# 140  Wanshouxigong      9  115.1
# 141  Wanshouxigong     10   87.4
# 142  Wanshouxigong     11    5.3
# 143  Wanshouxigong     12    0.0
#
# [144 rows x 3 columns]

# %%
temp_data = df_2016.groupby(['station','month'])['TEMP'].mean().reset_index()
print(temp_data)
temp_data.to_csv('temp_data.csv', index=False)
# Out:
#            station  month       TEMP
# 0     Aotizhongxin      1  -4.550000
# 1     Aotizhongxin      2   1.398420
# 2     Aotizhongxin      3   9.201882
# 3     Aotizhongxin      4  16.454722
# 4     Aotizhongxin      5  21.672849
# ..             ...    ...        ...
# 139  Wanshouxigong      8  27.863306
# 140  Wanshouxigong      9  22.197388
# 141  Wanshouxigong     10  13.338648
# 142  Wanshouxigong     11   4.414028
# 143  Wanshouxigong     12   0.640726
#
# [144 rows x 3 columns]

# %% [markdown]
# **Insight:**
# - Data berformat harian
# - Data mencapai skala tahun, bulan, hari dan memuat berbagai parameter kualitas udara.
# - presipitasi dan temperatur cukup menarik dianalisis karena menjadi satuan iklim yang tidak terpisahkan
# - Presipitasi dan temperatur menjadi salah satu parameter yang dapat digunakan untuk memprediksi curah hujan di masa mendatang.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana tren kumulatif hujan bulanan pada setiap Provinsi di China pada tahun 2016?
#
# ---

# %%
# Buat gambar
plt.figure(figsize=(15, 6))

# Memisahkan stasiun cuaca sehingga ditampilkan pada masing-masing gambar
unique_stations= rain_data['station'].unique()
num_stations= len(unique_stations)

# membuat warna yang random
colors = np.random.rand(num_stations, 3)  # Create an array of random RGB values

# membuat palet dan diatributkan pada setiap stasiun
palette = dict(zip(unique_stations, colors))

# membuat barplot
sns.barplot(x= 'month', y= 'RAIN', hue= 'station', data=rain_data, palette=palette)

plt.title('Total Rain per Month for Each Station in 2016')
plt.xlabel('Month')
plt.ylabel('Total Rain (mm)')
plt.legend(title='Station')
plt.xticks()
plt.show()

# %%
unique_stations= rain_data['station'].unique()
num_stations= len(unique_stations)

#membuat subplot dan membagi kolom menjadi 3
num_cols= 3  # Number of columns
num_rows= (num_stations + num_cols - 1) // num_cols

fig, axes= plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 5 * num_rows), sharex=True)

# Flatten the axes array for easier iteration
axes = axes.flatten()

for i, station in enumerate(unique_stations):
    ax = axes[i]
    station_data_subset = rain_data[rain_data['station'] == station]

    sns.lineplot(x='month', y='RAIN', data=station_data_subset, ax=ax)

    ax.set_title(f'{station} in 2016')
    ax.set_ylabel('Total Rain (mm)')
    ax.set_ylim(0, 400)

    if i >= num_stations - num_cols:
        ax.set_xlabel('Month')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Bagaimana tren rata-rata temperatur bulanan pada setiap Provinsi di China pada tahun 2016?

# %%
# Buat gambar
plt.figure(figsize=(15, 6))

# Memisahkan stasiun cuaca sehingga ditampilkan pada masing-masing gambar
unique_stations= temp_data['station'].unique()
num_stations= len(unique_stations)

# membuat warna yang random
colors = np.random.rand(num_stations, 3)  # Create an array of random RGB values

# membuat palet dan diatributkan pada setiap stasiun
palette =dict(zip(unique_stations, colors))

# membuat barplot
sns.barplot(x='month', y='TEMP', hue='station', data=temp_data, palette=palette)

plt.title('Total Rain per Month for Each Station in 2016')
plt.xlabel('Month')
plt.ylabel('Mean Temperature (celcius)')
plt.legend(title='Station')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
unique_stations= temp_data['station'].unique()
num_stations= len(unique_stations)

#membuat subplot dan membagi kolom menjadi 3
num_cols = 3  # Number of columns
num_rows = (num_stations + num_cols - 1) // num_cols  # Calculate rows needed

fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 5 * num_rows), sharex=True)

# Flatten the axes array for easier iteration
axes = axes.flatten()

for i, station in enumerate(unique_stations):
    ax = axes[i]
    temp_data_subset = temp_data[temp_data['station'] == station]

    sns.lineplot(x='month', y='TEMP', data=temp_data_subset, ax=ax)

    ax.set_title(f'{station} in 2016')
    ax.set_ylabel('mean temperature')
    ax.set_ylim(-5, 30)


    if i >= num_stations - num_cols:
        ax.set_xlabel('Month')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - Curah hujan per bulan memiliki bentuk gaussian dengan puncak bulan basah berada di bulan Juli dan bulan kering berada di Desember, Januari, dan Maret.
# - Temperatur tertinggi berada di bulan Juli dan Agustus dan temperatur terendah berada di bulan januari.
# - Presipitasi yang terjadi pada bulan januari dan februari dimungkinkan dalam bentuk salju karena temperatur yang relatif rendah
# - Huairou merupakan provinsi dengan temperatur terendah dan kumulatif curah hujan terendah dibanding daerah yang lain.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Curah hujan per bulan memiliki bentuk gaussian dengan puncak bulan basah berada di bulan Juli dan bulan kering berada di Desember, Januari, dan Maret.
# - Temperatur pada setiap provinsi tidak jauh berbeda kecuali daerah Huairou. Temperatur tertinggi berada di bulan Juli dan Agustus dan temperatur terendah berada di bulan Desember

# %%
pip freeze requirements.txt
# Out:
# absl-py==1.4.0
# accelerate==1.2.1
# aiohappyeyeballs==2.4.4
# aiohttp==3.11.11
# aiosignal==1.3.2
# alabaster==1.0.0
# albucore==0.0.19
# albumentations==1.4.20
# ale-py==0.10.1
# altair==5.5.0
# annotated-types==0.7.0
# anyio==3.7.1
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# array_record==0.6.0
# arviz==0.20.0
# astropy==6.1.7
# astropy-iers-data==0.2025.1.27.0.32.44
# astunparse==1.6.3
# atpublic==4.1.0
# attrs==25.1.0
# audioread==3.0.1
# autograd==1.7.0
# babel==2.16.0
# backcall==0.2.0
# beautifulsoup4==4.12.3
# bigframes==1.34.0
# bigquery-magics==0.5.0
# bleach==6.2.0
# blinker==1.9.0
# blis==0.7.11
# blosc2==3.0.0
# bokeh==3.6.2
# Bottleneck==1.4.2
# bqplot==0.12.44
# branca==0.8.1
# CacheControl==0.14.2
# cachetools==5.5.1
# catalogue==2.0.10
# certifi==2024.12.14
# cffi==1.17.1
# chardet==5.2.0
# charset-normalizer==3.4.1
# chex==0.1.88
# clarabel==0.9.0
# click==8.1.8
# cloudpathlib==0.20.0
# cloudpickle==3.1.1
# cmake==3.31.4
# cmdstanpy==1.2.5
# ...
